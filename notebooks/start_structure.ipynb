# %%
import random
with open('car-breakdown-prediction/test_CarBreakDown.csv', 'r') as file1:
    lines = file1.readlines()
    with open('car-breakdown-prediction/Template.csv', 'w') as file2:
        for line in lines:
           split_line = line.split(',')
           file2.write(f"{split_line[0]},{random.randint(0, 1)}\n")
