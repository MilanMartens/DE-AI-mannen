# %%
import random
with open('../csv/test/test_CarBreakDown.csv', 'r') as file1:
    lines = file1.readlines()
with open('../csv/Template.csv', 'w') as file2:
    file2.write("id,breakdown_next_30_days")
    for line in lines:
        split_line = line.split(',')
        file2.write(f"{split_line[0]},{random.randint(0, 1)}\n")
